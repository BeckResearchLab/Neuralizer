# %%
import plot
# Out:
# Using TensorFlow backend.

# %%
data = {"filename":'synthetic_data.tsv',"X_var":["A","B","C"],"Y_var":"y"}
X_test,Y_test,Y_new = plot.best_prediction(data)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(Y_test,Y_new)

# %%
plt.plot(X_test,Y_new)

# %%
plt.plot(X_test,Y_test)
