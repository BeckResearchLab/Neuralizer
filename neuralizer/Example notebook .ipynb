# %%
import model_create
# Out:
# Using TensorFlow backend.

# %%
#define the hyperparameter choices
params = {"activation_functions":["tanh","linear"],"units":[5,10,18],"hidden_layers":[1,2]}

#calrify predictors and response of the data
#Here the examples utilizes the synthetic data, data could be reviewed in data folder
data = {"filename":"synthetic_data.tsv","X_var":["A","B","C"],"Y_var":"y"}

# %%
# conduct initial search of the best structures of neural network
R,param = model_create.layer_search(data,0.2,42,0.0,params)
# Out:
# Complete search takes 504 iterations to finish
# 1	[['tanh', 5], ['tanh', 10], ['tanh', 18], ['linear', 5], ['linear', 10], ['linear', 18]]	72 iterations required
# [['tanh', 5]]
# running iteration 1
# create input layer with activation of tanh and units of 5
# create hidden layer 1 of activation tanh and units 5
# create output layer with activation of tanh and units of 1
#
# Epoch 00010: saving model to ./Results/collection1/intermediate_output1/weights-10-0.49.hdf5
#
# Epoch 00020: saving model to ./Results/collection1/intermediate_output1/weights-20-0.52.hdf5
# it already took 18.10 seconds
# {'layer_number': 1, 'starting_n': 1, 'best_R': 0.6449330681990239, 'best_param': [['tanh', 5], ['tanh', 5], 'tanh'], 'cumulative_time': 18.096440076828003}
#
# [['tanh', 5]]
# running iteration 2
# create input layer with activation of tanh and units of 5
# create hidden layer 1 of activation tanh and units 5
# create output layer with activation of linear and units of 1
#
# ...

# %% [markdown]
# * As shown above, the intermediate results would be stored in Results/collection folder
# * The activation functions could be customized which will be illustrated below.
# * During the iterations, the combinations, the order of iterations, R_squared value and cumulative time of training are printed for observing convenience.
# * Best results up to the last training are stored in .json file which will be shown below.
# * The training was interrupted on purpose, so that below how to resume training from where stopped could be displayed
