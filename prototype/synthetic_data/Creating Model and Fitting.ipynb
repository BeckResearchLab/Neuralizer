# %%
import pandas as pd
import numpy as np

# %% [markdown]
# * The following function is used for reading data and create x and y
# * It would take'csv' or 'tsv' file

# %%
import os
location = os.path.abspath('synthetic_data.tsv')
df_try = pd.read_csv('%s'%location)
print(location)
# Out:
# /Users/wangyuening/Documents/Research/Neuralizer/prototype/synthetic_data/synthetic_data.tsv

# %%
def read_file(filename,X_var,Y_var):
    location = os.path.abspath(filename)
    df = pd.read_csv('%s'%location,sep='\t')
    X = np.array(df[X_var].values)
    Y = np.array(df[Y_var].values)
    return X,Y

# %%
filename = 'synthetic_data.tsv'
X_var = ['A','B','C']
Y_var =['y']
X,Y = read_file(filename=filename,X_var=X_var,Y_var=Y_var)

# %%
X.shape
# Out:
# (9261, 3)

# %%
Y.shape
# Out:
# (9261, 1)

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
def split_train_test(X,Y,test_fraction,random_state):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_fraction, random_state=random_state)
    return X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, Y_train, Y_test = split_train_test(X,Y,0.20,42)

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras import *

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(20,input_dim=3,activation='tanh'))
model.add(keras.layers.Dense(1,activation='linear'))
                
                
model.compile(loss='mean_squared_error', optimizer='adam', metrics=[coeff_determination])
history = model.fit(X_train,Y_train,epochs=150, batch_size=10,validation_split=0.33)
# Out:
# Train on 4963 samples, validate on 2445 samples
# Epoch 1/150
# 4963/4963 [==============================] - 1s 138us/step - loss: 0.7070 - coeff_determination: 0.0441 - val_loss: 0.5921 - val_coeff_determination: 0.1362
# Epoch 2/150
# 4963/4963 [==============================] - 0s 92us/step - loss: 0.6016 - coeff_determination: 0.1588 - val_loss: 0.5641 - val_coeff_determination: 0.1768
# Epoch 3/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.5617 - coeff_determination: 0.2230 - val_loss: 0.5146 - val_coeff_determination: 0.2527
# Epoch 4/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.4902 - coeff_determination: 0.3184 - val_loss: 0.4253 - val_coeff_determination: 0.3930
# Epoch 5/150
# 4963/4963 [==============================] - 0s 92us/step - loss: 0.3843 - coeff_determination: 0.4487 - val_loss: 0.3162 - val_coeff_determination: 0.5439
# Epoch 6/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.2765 - coeff_determination: 0.6145 - val_loss: 0.2332 - val_coeff_determination: 0.6525
# Epoch 7/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.2052 - coeff_determination: 0.7170 - val_loss: 0.1830 - val_coeff_determination: 0.7255
# Epoch 8/150
# 4963/4963 [==============================] - 0s 97us/step - loss: 0.1615 - coeff_determination: 0.7586 - val_loss: 0.1452 - val_coeff_determination: 0.7774
# Epoch 9/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.1230 - coeff_determination: 0.8186 - val_loss: 0.1081 - val_coeff_determination: 0.8320
# Epoch 10/150
# 4963/4963 [==============================] - 0s 91us/step - loss: 0.0924 - coeff_determination: 0.8645 - val_loss: 0.0829 - val_coeff_determination: 0.8704
# Epoch 11/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.0731 - coeff_determination: 0.8858 - val_loss: 0.0650 - val_coeff_determination: 0.8977
# Epoch 12/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0589 - coeff_determination: 0.9080 - val_loss: 0.0537 - val_coeff_determination: 0.9153
# Epoch 13/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.0510 - coeff_determination: 0.9236 - val_loss: 0.0490 - val_coeff_determination: 0.9223
# Epoch 14/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0474 - coeff_determination: 0.9296 - val_loss: 0.0468 - val_coeff_determination: 0.9272
# Epoch 15/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0457 - coeff_determination: 0.9296 - val_loss: 0.0452 - val_coeff_determination: 0.9293
# Epoch 16/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0442 - coeff_determination: 0.9350 - val_loss: 0.0444 - val_coeff_determination: 0.9300
# Epoch 17/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0430 - coeff_determination: 0.9379 - val_loss: 0.0430 - val_coeff_determination: 0.9315
# Epoch 18/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0417 - coeff_determination: 0.9360 - val_loss: 0.0412 - val_coeff_determination: 0.9349
# Epoch 19/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0402 - coeff_determination: 0.9381 - val_loss: 0.0406 - val_coeff_determination: 0.9356
# Epoch 20/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0391 - coeff_determination: 0.9420 - val_loss: 0.0388 - val_coeff_determination: 0.9388
# Epoch 21/150
# 4963/4963 [==============================] - 1s 103us/step - loss: 0.0380 - coeff_determination: 0.9360 - val_loss: 0.0383 - val_coeff_determination: 0.9389
# Epoch 22/150
# 4963/4963 [==============================] - 0s 101us/step - loss: 0.0369 - coeff_determination: 0.9439 - val_loss: 0.0384 - val_coeff_determination: 0.9382
# Epoch 23/150
# 4963/4963 [==============================] - 0s 91us/step - loss: 0.0358 - coeff_determination: 0.9467 - val_loss: 0.0360 - val_coeff_determination: 0.9421
# Epoch 24/150
# 4963/4963 [==============================] - 1s 106us/step - loss: 0.0343 - coeff_determination: 0.9491 - val_loss: 0.0348 - val_coeff_determination: 0.9440
# Epoch 25/150
# 4963/4963 [==============================] - 1s 105us/step - loss: 0.0333 - coeff_determination: 0.9476 - val_loss: 0.0330 - val_coeff_determination: 0.9471
# Epoch 26/150
# 4963/4963 [==============================] - 1s 103us/step - loss: 0.0319 - coeff_determination: 0.9525 - val_loss: 0.0323 - val_coeff_determination: 0.9482
# Epoch 27/150
# 4963/4963 [==============================] - 0s 100us/step - loss: 0.0309 - coeff_determination: 0.9525 - val_loss: 0.0307 - val_coeff_determination: 0.9507
# Epoch 28/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.0301 - coeff_determination: 0.9553 - val_loss: 0.0314 - val_coeff_determination: 0.9494
# Epoch 29/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.0293 - coeff_determination: 0.9548 - val_loss: 0.0291 - val_coeff_determination: 0.9532
# Epoch 30/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0287 - coeff_determination: 0.9568 - val_loss: 0.0297 - val_coeff_determination: 0.9522
# Epoch 31/150
# 4963/4963 [==============================] - 0s 96us/step - loss: 0.0283 - coeff_determination: 0.9558 - val_loss: 0.0283 - val_coeff_determination: 0.9545
# Epoch 32/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.0278 - coeff_determination: 0.9600 - val_loss: 0.0295 - val_coeff_determination: 0.9522
# Epoch 33/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.0276 - coeff_determination: 0.9577 - val_loss: 0.0275 - val_coeff_determination: 0.9557
# Epoch 34/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0271 - coeff_determination: 0.9587 - val_loss: 0.0278 - val_coeff_determination: 0.9551
# Epoch 35/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0269 - coeff_determination: 0.9576 - val_loss: 0.0274 - val_coeff_determination: 0.9560
# Epoch 36/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0267 - coeff_determination: 0.9602 - val_loss: 0.0267 - val_coeff_determination: 0.9568
# Epoch 37/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0264 - coeff_determination: 0.9598 - val_loss: 0.0267 - val_coeff_determination: 0.9569
# Epoch 38/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0263 - coeff_determination: 0.9616 - val_loss: 0.0265 - val_coeff_determination: 0.9573
# Epoch 39/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0263 - coeff_determination: 0.9611 - val_loss: 0.0261 - val_coeff_determination: 0.9581
# Epoch 40/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0260 - coeff_determination: 0.9578 - val_loss: 0.0277 - val_coeff_determination: 0.9553
# Epoch 41/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0261 - coeff_determination: 0.9602 - val_loss: 0.0271 - val_coeff_determination: 0.9562
# Epoch 42/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0257 - coeff_determination: 0.9603 - val_loss: 0.0258 - val_coeff_determination: 0.9586
# Epoch 43/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0257 - coeff_determination: 0.9621 - val_loss: 0.0254 - val_coeff_determination: 0.9591
# Epoch 44/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0256 - coeff_determination: 0.9632 - val_loss: 0.0263 - val_coeff_determination: 0.9576
# Epoch 45/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0258 - coeff_determination: 0.9614 - val_loss: 0.0255 - val_coeff_determination: 0.9591
# Epoch 46/150
# 4963/4963 [==============================] - 1s 103us/step - loss: 0.0257 - coeff_determination: 0.9630 - val_loss: 0.0252 - val_coeff_determination: 0.9595
# Epoch 47/150
# 4963/4963 [==============================] - 0s 100us/step - loss: 0.0252 - coeff_determination: 0.9614 - val_loss: 0.0261 - val_coeff_determination: 0.9578
# Epoch 48/150
# 4963/4963 [==============================] - 0s 98us/step - loss: 0.0253 - coeff_determination: 0.9618 - val_loss: 0.0254 - val_coeff_determination: 0.9591
# Epoch 49/150
# 4963/4963 [==============================] - 0s 95us/step - loss: 0.0250 - coeff_determination: 0.9601 - val_loss: 0.0248 - val_coeff_determination: 0.9602
# Epoch 50/150
# 4963/4963 [==============================] - 0s 91us/step - loss: 0.0252 - coeff_determination: 0.9615 - val_loss: 0.0263 - val_coeff_determination: 0.9574
# Epoch 51/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0249 - coeff_determination: 0.9621 - val_loss: 0.0247 - val_coeff_determination: 0.9602
# Epoch 52/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0250 - coeff_determination: 0.9633 - val_loss: 0.0244 - val_coeff_determination: 0.9606
# Epoch 53/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0248 - coeff_determination: 0.9619 - val_loss: 0.0247 - val_coeff_determination: 0.9603
# Epoch 54/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0248 - coeff_determination: 0.9612 - val_loss: 0.0248 - val_coeff_determination: 0.9600
# Epoch 55/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0247 - coeff_determination: 0.9637 - val_loss: 0.0247 - val_coeff_determination: 0.9604
# Epoch 56/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0247 - coeff_determination: 0.9595 - val_loss: 0.0240 - val_coeff_determination: 0.9613
# Epoch 57/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0245 - coeff_determination: 0.9627 - val_loss: 0.0244 - val_coeff_determination: 0.9606
# Epoch 58/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0247 - coeff_determination: 0.9619 - val_loss: 0.0240 - val_coeff_determination: 0.9616
# Epoch 59/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0243 - coeff_determination: 0.9615 - val_loss: 0.0243 - val_coeff_determination: 0.9610
# Epoch 60/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0243 - coeff_determination: 0.9620 - val_loss: 0.0241 - val_coeff_determination: 0.9612
# Epoch 61/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0244 - coeff_determination: 0.9623 - val_loss: 0.0240 - val_coeff_determination: 0.9613
# Epoch 62/150
# 4963/4963 [==============================] - 0s 86us/step - loss: 0.0243 - coeff_determination: 0.9619 - val_loss: 0.0243 - val_coeff_determination: 0.9609
# Epoch 63/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0241 - coeff_determination: 0.9628 - val_loss: 0.0247 - val_coeff_determination: 0.9601
# Epoch 64/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0242 - coeff_determination: 0.9623 - val_loss: 0.0234 - val_coeff_determination: 0.9624
# Epoch 65/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0241 - coeff_determination: 0.9642 - val_loss: 0.0236 - val_coeff_determination: 0.9620
# Epoch 66/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0239 - coeff_determination: 0.9638 - val_loss: 0.0241 - val_coeff_determination: 0.9612
# Epoch 67/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0240 - coeff_determination: 0.9635 - val_loss: 0.0235 - val_coeff_determination: 0.9621
# Epoch 68/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0240 - coeff_determination: 0.9644 - val_loss: 0.0235 - val_coeff_determination: 0.9622
# Epoch 69/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0238 - coeff_determination: 0.9653 - val_loss: 0.0234 - val_coeff_determination: 0.9622
# Epoch 70/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0238 - coeff_determination: 0.9628 - val_loss: 0.0237 - val_coeff_determination: 0.9619
# Epoch 71/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0237 - coeff_determination: 0.9636 - val_loss: 0.0230 - val_coeff_determination: 0.9629
# Epoch 72/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0237 - coeff_determination: 0.9638 - val_loss: 0.0240 - val_coeff_determination: 0.9612
# Epoch 73/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0238 - coeff_determination: 0.9625 - val_loss: 0.0230 - val_coeff_determination: 0.9628
# Epoch 74/150
# 4963/4963 [==============================] - 0s 93us/step - loss: 0.0234 - coeff_determination: 0.9667 - val_loss: 0.0232 - val_coeff_determination: 0.9626
# Epoch 75/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0236 - coeff_determination: 0.9658 - val_loss: 0.0235 - val_coeff_determination: 0.9620
# Epoch 76/150
# 4963/4963 [==============================] - 0s 90us/step - loss: 0.0236 - coeff_determination: 0.9655 - val_loss: 0.0241 - val_coeff_determination: 0.9610
# Epoch 77/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0236 - coeff_determination: 0.9577 - val_loss: 0.0234 - val_coeff_determination: 0.9621
# Epoch 78/150
# 4963/4963 [==============================] - 1s 110us/step - loss: 0.0234 - coeff_determination: 0.9627 - val_loss: 0.0239 - val_coeff_determination: 0.9613
# Epoch 79/150
# 4963/4963 [==============================] - 0s 85us/step - loss: 0.0235 - coeff_determination: 0.9633 - val_loss: 0.0233 - val_coeff_determination: 0.9623
# Epoch 80/150
# 4963/4963 [==============================] - 0s 87us/step - loss: 0.0235 - coeff_determination: 0.9631 - val_loss: 0.0233 - val_coeff_determination: 0.9625
# Epoch 81/150
# 4963/4963 [==============================] - 0s 91us/step - loss: 0.0234 - coeff_determination: 0.9612 - val_loss: 0.0228 - val_coeff_determination: 0.9633
# Epoch 82/150
# 4963/4963 [==============================] - 0s 91us/step - loss: 0.0233 - coeff_determination: 0.9651 - val_loss: 0.0225 - val_coeff_determination: 0.9637
# Epoch 83/150
# 4963/4963 [==============================] - 0s 86us/step - loss: 0.0233 - coeff_determination: 0.9634 - val_loss: 0.0230 - val_coeff_determination: 0.9630
# Epoch 84/150
# 4963/4963 [==============================] - 1s 101us/step - loss: 0.0231 - coeff_determination: 0.9653 - val_loss: 0.0236 - val_coeff_determination: 0.9617
# Epoch 85/150
# 4963/4963 [==============================] - 1s 101us/step - loss: 0.0232 - coeff_determination: 0.9666 - val_loss: 0.0236 - val_coeff_determination: 0.9617
# Epoch 86/150
# 4963/4963 [==============================] - 0s 98us/step - loss: 0.0232 - coeff_determination: 0.9612 - val_loss: 0.0223 - val_coeff_determination: 0.9641
# Epoch 87/150
# 4963/4963 [==============================] - 0s 99us/step - loss: 0.0232 - coeff_determination: 0.9651 - val_loss: 0.0225 - val_coeff_determination: 0.9636
# Epoch 88/150
# 4963/4963 [==============================] - 0s 99us/step - loss: 0.0231 - coeff_determination: 0.9666 - val_loss: 0.0234 - val_coeff_determination: 0.9622
# Epoch 89/150
# 4963/4963 [==============================] - 0s 95us/step - loss: 0.0231 - coeff_determination: 0.9656 - val_loss: 0.0231 - val_coeff_determination: 0.9626
# Epoch 90/150
# 4963/4963 [==============================] - 0s 94us/step - loss: 0.0230 - coeff_determination: 0.9644 - val_loss: 0.0224 - val_coeff_determination: 0.9639
# Epoch 91/150
# 4963/4963 [==============================] - 0s 97us/step - loss: 0.0230 - coeff_determination: 0.9610 - val_loss: 0.0237 - val_coeff_determination: 0.9615
# Epoch 92/150
# 4963/4963 [==============================] - 0s 98us/step - loss: 0.0230 - coeff_determination: 0.9661 - val_loss: 0.0226 - val_coeff_determination: 0.9636
# Epoch 93/150
# 4963/4963 [==============================] - 0s 97us/step - loss: 0.0230 - coeff_determination: 0.9654 - val_loss: 0.0225 - val_coeff_determination: 0.9635
# Epoch 94/150
# 4963/4963 [==============================] - 0s 98us/step - loss: 0.0229 - coeff_determination: 0.9658 - val_loss: 0.0222 - val_coeff_determination: 0.9642
# Epoch 95/150
# 4963/4963 [==============================] - 0s 100us/step - loss: 0.0230 - coeff_determination: 0.9652 - val_loss: 0.0221 - val_coeff_determination: 0.9644
# Epoch 96/150
# 4963/4963 [==============================] - 0s 97us/step - loss: 0.0229 - coeff_determination: 0.9647 - val_loss: 0.0223 - val_coeff_determination: 0.9639
# Epoch 97/150
# 4963/4963 [==============================] - 0s 98us/step - loss: 0.0228 - coeff_determination: 0.9655 - val_loss: 0.0224 - val_coeff_determination: 0.9637
# Epoch 98/150
# 4963/4963 [==============================] - 0s 91us/step - loss: 0.0227 - coeff_determination: 0.9629 - val_loss: 0.0227 - val_coeff_determination: 0.9633
# Epoch 99/150
# 4963/4963 [==============================] - 1s 105us/step - loss: 0.0230 - coeff_determination: 0.9648 - val_loss: 0.0225 - val_coeff_determination: 0.9638
# Epoch 100/150
# 4963/4963 [==============================] - 1s 105us/step - loss: 0.0227 - coeff_determination: 0.9646 - val_loss: 0.0221 - val_coeff_determination: 0.9641
# Epoch 101/150
# 4963/4963 [==============================] - 0s 92us/step - loss: 0.0228 - coeff_determination: 0.9654 - val_loss: 0.0220 - val_coeff_determination: 0.9646
# Epoch 102/150
# 4963/4963 [==============================] - 0s 92us/step - loss: 0.0226 - coeff_determination: 0.9645 - val_loss: 0.0231 - val_coeff_determination: 0.9624
# Epoch 103/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0226 - coeff_determination: 0.9650 - val_loss: 0.0220 - val_coeff_determination: 0.9646
# Epoch 104/150
# 4963/4963 [==============================] - 0s 88us/step - loss: 0.0228 - coeff_determination: 0.9669 - val_loss: 0.0230 - val_coeff_determination: 0.9627
# Epoch 105/150
# 4963/4963 [==============================] - 0s 96us/step - loss: 0.0226 - coeff_determination: 0.9655 - val_loss: 0.0221 - val_coeff_determination: 0.9643
# Epoch 106/150
# 4963/4963 [==============================] - 0s 100us/step - loss: 0.0225 - coeff_determination: 0.9683 - val_loss: 0.0225 - val_coeff_determination: 0.9634
# Epoch 107/150
# 4963/4963 [==============================] - 0s 98us/step - loss: 0.0224 - coeff_determination: 0.9653 - val_loss: 0.0217 - val_coeff_determination: 0.9649
# Epoch 108/150
# 4963/4963 [==============================] - 0s 101us/step - loss: 0.0225 - coeff_determination: 0.9650 - val_loss: 0.0219 - val_coeff_determination: 0.9645
# Epoch 109/150
# 4963/4963 [==============================] - 0s 94us/step - loss: 0.0224 - coeff_determination: 0.9680 - val_loss: 0.0217 - val_coeff_determination: 0.9651
# Epoch 110/150
# 4963/4963 [==============================] - 1s 106us/step - loss: 0.0225 - coeff_determination: 0.9665 - val_loss: 0.0217 - val_coeff_determination: 0.9650
# Epoch 111/150
# 4963/4963 [==============================] - 0s 89us/step - loss: 0.0224 - coeff_determination: 0.9645 - val_loss: 0.0248 - val_coeff_determination: 0.9596
# Epoch 112/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0225 - coeff_determination: 0.9662 - val_loss: 0.0217 - val_coeff_determination: 0.9650
# Epoch 113/150
# 4963/4963 [==============================] - 0s 84us/step - loss: 0.0223 - coeff_determination: 0.9675 - val_loss: 0.0215 - val_coeff_determination: 0.9652
# Epoch 114/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0224 - coeff_determination: 0.9665 - val_loss: 0.0218 - val_coeff_determination: 0.9649
# Epoch 115/150
# 4963/4963 [==============================] - 0s 86us/step - loss: 0.0223 - coeff_determination: 0.9646 - val_loss: 0.0220 - val_coeff_determination: 0.9646
# Epoch 116/150
# 4963/4963 [==============================] - 0s 84us/step - loss: 0.0224 - coeff_determination: 0.9621 - val_loss: 0.0213 - val_coeff_determination: 0.9656
# Epoch 117/150
# 4963/4963 [==============================] - 0s 84us/step - loss: 0.0222 - coeff_determination: 0.9640 - val_loss: 0.0234 - val_coeff_determination: 0.9619
# Epoch 118/150
# 4963/4963 [==============================] - 0s 82us/step - loss: 0.0222 - coeff_determination: 0.9674 - val_loss: 0.0221 - val_coeff_determination: 0.9641
# Epoch 119/150
# 4963/4963 [==============================] - 0s 81us/step - loss: 0.0221 - coeff_determination: 0.9654 - val_loss: 0.0210 - val_coeff_determination: 0.9660
# Epoch 120/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0222 - coeff_determination: 0.9677 - val_loss: 0.0222 - val_coeff_determination: 0.9643
# Epoch 121/150
# 4963/4963 [==============================] - 0s 79us/step - loss: 0.0222 - coeff_determination: 0.9665 - val_loss: 0.0220 - val_coeff_determination: 0.9644
# Epoch 122/150
# 4963/4963 [==============================] - 0s 82us/step - loss: 0.0221 - coeff_determination: 0.9669 - val_loss: 0.0224 - val_coeff_determination: 0.9640
# Epoch 123/150
# 4963/4963 [==============================] - 0s 84us/step - loss: 0.0221 - coeff_determination: 0.9661 - val_loss: 0.0212 - val_coeff_determination: 0.9659
# Epoch 124/150
# 4963/4963 [==============================] - 0s 82us/step - loss: 0.0220 - coeff_determination: 0.9676 - val_loss: 0.0215 - val_coeff_determination: 0.9653
# Epoch 125/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0221 - coeff_determination: 0.9661 - val_loss: 0.0212 - val_coeff_determination: 0.9658
# Epoch 126/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0220 - coeff_determination: 0.9670 - val_loss: 0.0217 - val_coeff_determination: 0.9650
# Epoch 127/150
# 4963/4963 [==============================] - 0s 82us/step - loss: 0.0221 - coeff_determination: 0.9647 - val_loss: 0.0225 - val_coeff_determination: 0.9635
# Epoch 128/150
# 4963/4963 [==============================] - 0s 82us/step - loss: 0.0218 - coeff_determination: 0.9663 - val_loss: 0.0219 - val_coeff_determination: 0.9647
# Epoch 129/150
# 4963/4963 [==============================] - 0s 82us/step - loss: 0.0218 - coeff_determination: 0.9661 - val_loss: 0.0221 - val_coeff_determination: 0.9642
# Epoch 130/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0219 - coeff_determination: 0.9650 - val_loss: 0.0225 - val_coeff_determination: 0.9635
# Epoch 131/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0219 - coeff_determination: 0.9680 - val_loss: 0.0211 - val_coeff_determination: 0.9661
# Epoch 132/150
# 4963/4963 [==============================] - 0s 84us/step - loss: 0.0217 - coeff_determination: 0.9659 - val_loss: 0.0209 - val_coeff_determination: 0.9662
# Epoch 133/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0218 - coeff_determination: 0.9667 - val_loss: 0.0207 - val_coeff_determination: 0.9666
# Epoch 134/150
# 4963/4963 [==============================] - 0s 85us/step - loss: 0.0218 - coeff_determination: 0.9662 - val_loss: 0.0214 - val_coeff_determination: 0.9655
# Epoch 135/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0218 - coeff_determination: 0.9678 - val_loss: 0.0208 - val_coeff_determination: 0.9664
# Epoch 136/150
# 4963/4963 [==============================] - 0s 82us/step - loss: 0.0218 - coeff_determination: 0.9630 - val_loss: 0.0215 - val_coeff_determination: 0.9647
# Epoch 137/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0218 - coeff_determination: 0.9660 - val_loss: 0.0215 - val_coeff_determination: 0.9653
# Epoch 138/150
# 4963/4963 [==============================] - 0s 82us/step - loss: 0.0216 - coeff_determination: 0.9692 - val_loss: 0.0210 - val_coeff_determination: 0.9661
# Epoch 139/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0218 - coeff_determination: 0.9635 - val_loss: 0.0208 - val_coeff_determination: 0.9662
# Epoch 140/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0216 - coeff_determination: 0.9694 - val_loss: 0.0210 - val_coeff_determination: 0.9660
# Epoch 141/150
# 4963/4963 [==============================] - 0s 82us/step - loss: 0.0214 - coeff_determination: 0.9667 - val_loss: 0.0216 - val_coeff_determination: 0.9654
# Epoch 142/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0217 - coeff_determination: 0.9661 - val_loss: 0.0208 - val_coeff_determination: 0.9664
# Epoch 143/150
# 4963/4963 [==============================] - 0s 84us/step - loss: 0.0215 - coeff_determination: 0.9691 - val_loss: 0.0204 - val_coeff_determination: 0.9668
# Epoch 144/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0216 - coeff_determination: 0.9675 - val_loss: 0.0206 - val_coeff_determination: 0.9668
# Epoch 145/150
# 4963/4963 [==============================] - 0s 84us/step - loss: 0.0215 - coeff_determination: 0.9664 - val_loss: 0.0208 - val_coeff_determination: 0.9662
# Epoch 146/150
# 4963/4963 [==============================] - 0s 84us/step - loss: 0.0216 - coeff_determination: 0.9640 - val_loss: 0.0205 - val_coeff_determination: 0.9669
# Epoch 147/150
# 4963/4963 [==============================] - 0s 84us/step - loss: 0.0215 - coeff_determination: 0.9676 - val_loss: 0.0203 - val_coeff_determination: 0.9672
# Epoch 148/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0215 - coeff_determination: 0.9660 - val_loss: 0.0213 - val_coeff_determination: 0.9658
# Epoch 149/150
# 4963/4963 [==============================] - 0s 82us/step - loss: 0.0215 - coeff_determination: 0.9678 - val_loss: 0.0207 - val_coeff_determination: 0.9664
# Epoch 150/150
# 4963/4963 [==============================] - 0s 83us/step - loss: 0.0214 - coeff_determination: 0.9673 - val_loss: 0.0220 - val_coeff_determination: 0.9640

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['coeff_determination'])
plt.plot(history.history['val_coeff_determination'])
plt.title('model fitting')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import keras.backend as K

def coeff_determination(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
scores = model.evaluate(X_test,Y_test)
print (scores)
print (model.metrics_names)
print("%s: %.2f" % (model.metrics_names[1], scores[1]))
# Out:
# 1853/1853 [==============================] - 0s 10us/step
# [0.023342131689810072, 0.9735797824437594]
# ['loss', 'coeff_determination']
# coeff_determination: 0.97

# %%
X_new = X_train[:1000]
Y_new = Y_train[:1000]

# %%
def model_search_old(activation,lr,nodes,input_dim,output_dim):
    best_R = 0.0
    best_lr = 0.0
    best_activation = ['none','none','none']
    best_nodes = ['none']
    for lr_n in lr:
        for activation1 in activation:
            for acttivation2 in activation:
                for activation3 in activation:
                    for nodes_n in nodes:
                        model = keras.Sequential()
                        model.add(keras.layers.Dense(10,input_dim=input_dim,activation=activation2)
                        model.add(keras.layers.Dense(nodes_n,activation=activation2))
                        model.add(keras.layers.Dense(output_dim,activation=activation3))
                
                        model.compile(loss='mean_squared_error', optimizer=Adam(lr=lr_n), metrics=[coeff_determination])
                        history = model.fit(X_train,Y_train,epochs=15, batch_size=10,validation_split=0.33)
                        
                        scores = model.evaulate(X_test,Y_test)
                        print(scores)
                        if scores[1]>0.985:
                            best_activation = [activation1,activation2,activation3]
                            best_R = scores[1]
                            best_nodes = nodes_n
                            best_lr = lr_n
                            break
                        elif scores[1]>best_R:
                            best_activation = [activation1,activation2,activation3]
                            best_R = scores[1]
                            best_nodes = nodes_n
                            best_lr = lr_n
                        else:
                            pass
    print (best_R, best_activation,best_nodes,best_lr)
# Out:
#   File "<ipython-input-91-8afec8440656>", line 13
#     model.add(keras.layers.Dense(nodes_n,activation=activation2))
#         ^
# SyntaxError: invalid syntax

# %%
def model_search(X_train,Y_train,X_test,Y_test,
    input_dim,output_dim,layers,activation_functions=['tanh','softmax','linear']):
    iterations = len(activation_functions)**(layers + 2)
    inner_iterations = len(activation_functions)**layers
    af_combs = make_pairwise_list(max_depth=layers, options=activation_functions)
    print(f'{layers}\t{activation_functions}\t{iterations} iterations required')
    best_R = 0.0
    best_activation = []
    iteration_n = 1
    for n in range(layers):
        best_activation.append('none')
    best_activation = []
    for inner_iteration in range(inner_iterations):
        for activation_in in activation_functions:
            for layer in range(layers):
                inner_list = []
                inner_list.append(af_combs[inner_iteration][layer])
                for activation_out in activation_functions:
                    print(f"running iteration {iteration_n}")
                    parameter_list = []
                    parameter_list.append(activation_in)
                    parameter_list.extend(inner_list)
                    parameter_list.append(activation_out)
                    print(f"create input layer with activation of {activation_in}")
                    
                    model = keras.Sequential()
                    model.add(keras.layers.Dense(10,input_dim = input_dim,activation=activation_in))
                    for i in range(len(inner_list)):
                        print(f"create hidden layer {layer} of type {inner_list[i]}")
                        model.add(keras.layers.Dense(20,activation = inner_list[i]))
                    print(f"create output layer with activation of {activation_out}")
                    model.add(keras.layers.Dense(output_dim,activation=activation_out))
                    model.compile(loss='mean_squared_error', optimizer='adam', 
                                  metrics=[coeff_determination])
                    history = model.fit(X_train,Y_train,epochs=50, batch_size=10,validation_split=0.33)
                    scores = model.evaluate(X_test,Y_test)
                    print(scores[1])
                    iteration_n += 1 
                    if scores[1]>best_R:
                        best_activation = parameter_list
                        best_R = scores[1]
                    else:
                        pass
        print("")
    print(best_activation)
    print(best_R)

# %%
model_search(X_train=X_new,Y_train=Y_new,X_test=X_test,Y_test=Y_test,
             input_dim=3,output_dim=1,layers=1)
# Out:
# 1	['tanh', 'softmax', 'linear']	27 iterations required
# running iteration 1
# create input layer with activation of tanh
# create hidden layer 0 of type tanh
# create output layer with activation of tanh
# Train on 669 samples, validate on 331 samples
# Epoch 1/50
# 669/669 [==============================] - 1s 2ms/step - loss: 0.9299 - coeff_determination: -0.3594 - val_loss: 0.6478 - val_coeff_determination: -16154.7429
# Epoch 2/50
# 669/669 [==============================] - 0s 172us/step - loss: 0.5513 - coeff_determination: 0.1400 - val_loss: 0.4526 - val_coeff_determination: -6732.5275
# Epoch 3/50
# 669/669 [==============================] - 0s 162us/step - loss: 0.4203 - coeff_determination: 0.4087 - val_loss: 0.3816 - val_coeff_determination: -5098.9845
# Epoch 4/50
# 669/669 [==============================] - 0s 153us/step - loss: 0.3717 - coeff_determination: 0.4668 - val_loss: 0.3542 - val_coeff_determination: -4708.8445
# Epoch 5/50
# 669/669 [==============================] - 0s 153us/step - loss: 0.3519 - coeff_determination: 0.4613 - val_loss: 0.3390 - val_coeff_determination: -4567.2249
# Epoch 6/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.3422 - coeff_determination: 0.5305 - val_loss: 0.3343 - val_coeff_determination: -4509.8457
# Epoch 7/50
# 669/669 [==============================] - 0s 157us/step - loss: 0.3381 - coeff_determination: 0.5132 - val_loss: 0.3305 - val_coeff_determination: -4484.9443
# Epoch 8/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.3348 - coeff_determination: 0.5180 - val_loss: 0.3315 - val_coeff_determination: -4468.4614
# Epoch 9/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.3342 - coeff_determination: 0.5279 - val_loss: 0.3277 - val_coeff_determination: -4461.9510
# Epoch 10/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.3320 - coeff_determination: 0.4806 - val_loss: 0.3249 - val_coeff_determination: -4456.0914
# Epoch 11/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.3315 - coeff_determination: 0.5053 - val_loss: 0.3246 - val_coeff_determination: -4452.7735
# Epoch 12/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.3313 - coeff_determination: 0.4783 - val_loss: 0.3258 - val_coeff_determination: -4449.4147
# Epoch 13/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.3301 - coeff_determination: 0.5264 - val_loss: 0.3243 - val_coeff_determination: -4447.4668
# Epoch 14/50
# 669/669 [==============================] - 0s 174us/step - loss: 0.3298 - coeff_determination: 0.5177 - val_loss: 0.3236 - val_coeff_determination: -4446.0269
# Epoch 15/50
# 669/669 [==============================] - 0s 162us/step - loss: 0.3287 - coeff_determination: 0.5087 - val_loss: 0.3235 - val_coeff_determination: -4444.5555
# Epoch 16/50
# 669/669 [==============================] - 0s 162us/step - loss: 0.3277 - coeff_determination: 0.4873 - val_loss: 0.3212 - val_coeff_determination: -4443.4887
# Epoch 17/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.3278 - coeff_determination: 0.4914 - val_loss: 0.3171 - val_coeff_determination: -4442.8492
# Epoch 18/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.3280 - coeff_determination: 0.5387 - val_loss: 0.3167 - val_coeff_determination: -4442.8156
# Epoch 19/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.3245 - coeff_determination: 0.5306 - val_loss: 0.3277 - val_coeff_determination: -4440.5480
# Epoch 20/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.3260 - coeff_determination: 0.5774 - val_loss: 0.3148 - val_coeff_determination: -4441.0067
# Epoch 21/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.3242 - coeff_determination: 0.5605 - val_loss: 0.3154 - val_coeff_determination: -4440.3554
# Epoch 22/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.3234 - coeff_determination: 0.5564 - val_loss: 0.3147 - val_coeff_determination: -4440.4318
# Epoch 23/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.3219 - coeff_determination: 0.5323 - val_loss: 0.3139 - val_coeff_determination: -4440.3946
# Epoch 24/50
# 669/669 [==============================] - 0s 158us/step - loss: 0.3207 - coeff_determination: 0.5198 - val_loss: 0.3097 - val_coeff_determination: -4440.8899
# Epoch 25/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.3202 - coeff_determination: 0.5083 - val_loss: 0.3116 - val_coeff_determination: -4439.7151
# Epoch 26/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.3201 - coeff_determination: 0.5539 - val_loss: 0.3107 - val_coeff_determination: -4439.9539
# Epoch 27/50
# 669/669 [==============================] - 0s 157us/step - loss: 0.3166 - coeff_determination: 0.5395 - val_loss: 0.3105 - val_coeff_determination: -4439.0267
# Epoch 28/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.3161 - coeff_determination: 0.5177 - val_loss: 0.3130 - val_coeff_determination: -4439.8554
# Epoch 29/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.3147 - coeff_determination: 0.5366 - val_loss: 0.3058 - val_coeff_determination: -4439.4292
# Epoch 30/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.3129 - coeff_determination: 0.5689 - val_loss: 0.3023 - val_coeff_determination: -4439.2468
# Epoch 31/50
# 669/669 [==============================] - 0s 159us/step - loss: 0.3109 - coeff_determination: 0.5001 - val_loss: 0.3016 - val_coeff_determination: -4439.1017
# Epoch 32/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.3090 - coeff_determination: 0.5654 - val_loss: 0.2960 - val_coeff_determination: -4438.5731
# Epoch 33/50
# 669/669 [==============================] - 0s 157us/step - loss: 0.3085 - coeff_determination: 0.5494 - val_loss: 0.2978 - val_coeff_determination: -4438.0182
# Epoch 34/50
# 669/669 [==============================] - 0s 167us/step - loss: 0.3062 - coeff_determination: 0.5221 - val_loss: 0.2934 - val_coeff_determination: -4438.0267
# Epoch 35/50
# 669/669 [==============================] - 0s 160us/step - loss: 0.3036 - coeff_determination: 0.5909 - val_loss: 0.2907 - val_coeff_determination: -4437.9572
# Epoch 36/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.3039 - coeff_determination: 0.5172 - val_loss: 0.2908 - val_coeff_determination: -4437.8756
# Epoch 37/50
# 669/669 [==============================] - 0s 159us/step - loss: 0.3010 - coeff_determination: 0.5166 - val_loss: 0.2872 - val_coeff_determination: -4437.6082
# Epoch 38/50
# 669/669 [==============================] - 0s 157us/step - loss: 0.2986 - coeff_determination: 0.5752 - val_loss: 0.2871 - val_coeff_determination: -4437.0059
# Epoch 39/50
# 669/669 [==============================] - 0s 182us/step - loss: 0.2988 - coeff_determination: 0.5664 - val_loss: 0.2862 - val_coeff_determination: -4436.6810
# Epoch 40/50
# 669/669 [==============================] - 0s 178us/step - loss: 0.2953 - coeff_determination: 0.5534 - val_loss: 0.2864 - val_coeff_determination: -4436.2998
# Epoch 41/50
# 669/669 [==============================] - 0s 157us/step - loss: 0.2952 - coeff_determination: 0.5599 - val_loss: 0.2823 - val_coeff_determination: -4436.1196
# Epoch 42/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.2936 - coeff_determination: 0.5846 - val_loss: 0.2805 - val_coeff_determination: -4436.6222
# Epoch 43/50
# 669/669 [==============================] - 0s 158us/step - loss: 0.2913 - coeff_determination: 0.5989 - val_loss: 0.2817 - val_coeff_determination: -4436.3767
# Epoch 44/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.2910 - coeff_determination: 0.5551 - val_loss: 0.2783 - val_coeff_determination: -4435.7909
# Epoch 45/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.2896 - coeff_determination: 0.6067 - val_loss: 0.2803 - val_coeff_determination: -4435.1623
# Epoch 46/50
# 669/669 [==============================] - 0s 159us/step - loss: 0.2890 - coeff_determination: 0.5727 - val_loss: 0.2776 - val_coeff_determination: -4435.0542
# Epoch 47/50
# 669/669 [==============================] - 0s 157us/step - loss: 0.2882 - coeff_determination: 0.5670 - val_loss: 0.2770 - val_coeff_determination: -4434.7097
# Epoch 48/50
# 669/669 [==============================] - 0s 151us/step - loss: 0.2876 - coeff_determination: 0.5782 - val_loss: 0.2775 - val_coeff_determination: -4434.6601
# Epoch 49/50
# 669/669 [==============================] - 0s 152us/step - loss: 0.2866 - coeff_determination: 0.5692 - val_loss: 0.2762 - val_coeff_determination: -4434.3686
# Epoch 50/50
# 669/669 [==============================] - 0s 160us/step - loss: 0.2859 - coeff_determination: 0.6075 - val_loss: 0.2742 - val_coeff_determination: -4434.7879
# 1853/1853 [==============================] - 0s 21us/step
# 0.6526974127605292
# running iteration 2
# create input layer with activation of tanh
# create hidden layer 0 of type tanh
# create output layer with activation of softmax
# Train on 669 samples, validate on 331 samples
# Epoch 1/50
# 669/669 [==============================] - 1s 2ms/step - loss: 3.8453 - coeff_determination: -5.0648 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 2/50
# 669/669 [==============================] - 0s 164us/step - loss: 3.8453 - coeff_determination: -5.3728 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 3/50
# 669/669 [==============================] - 0s 165us/step - loss: 3.8453 - coeff_determination: -5.7307 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 4/50
# 669/669 [==============================] - 0s 155us/step - loss: 3.8453 - coeff_determination: -5.7482 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 5/50
# 669/669 [==============================] - 0s 152us/step - loss: 3.8453 - coeff_determination: -4.9878 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 6/50
# 669/669 [==============================] - 0s 176us/step - loss: 3.8453 - coeff_determination: -5.1704 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 7/50
# 669/669 [==============================] - 0s 159us/step - loss: 3.8453 - coeff_determination: -5.2526 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 8/50
# 669/669 [==============================] - 0s 152us/step - loss: 3.8453 - coeff_determination: -5.3416 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 9/50
# 669/669 [==============================] - 0s 150us/step - loss: 3.8453 - coeff_determination: -4.6273 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 10/50
# 669/669 [==============================] - 0s 165us/step - loss: 3.8453 - coeff_determination: -4.4966 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 11/50
# 669/669 [==============================] - 0s 163us/step - loss: 3.8453 - coeff_determination: -4.9056 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 12/50
# 669/669 [==============================] - 0s 159us/step - loss: 3.8453 - coeff_determination: -5.2183 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 13/50
# 669/669 [==============================] - 0s 154us/step - loss: 3.8453 - coeff_determination: -4.3770 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 14/50
# 669/669 [==============================] - 0s 153us/step - loss: 3.8453 - coeff_determination: -5.5266 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 15/50
# 669/669 [==============================] - 0s 167us/step - loss: 3.8453 - coeff_determination: -5.6985 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 16/50
# 669/669 [==============================] - 0s 161us/step - loss: 3.8453 - coeff_determination: -4.3207 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 17/50
# 669/669 [==============================] - 0s 161us/step - loss: 3.8453 - coeff_determination: -4.6825 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 18/50
# 669/669 [==============================] - 0s 157us/step - loss: 3.8453 - coeff_determination: -4.8928 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 19/50
# 669/669 [==============================] - 0s 155us/step - loss: 3.8453 - coeff_determination: -5.3215 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 20/50
# 669/669 [==============================] - 0s 153us/step - loss: 3.8453 - coeff_determination: -5.2142 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 21/50
# 669/669 [==============================] - 0s 158us/step - loss: 3.8453 - coeff_determination: -5.0225 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 22/50
# 669/669 [==============================] - 0s 166us/step - loss: 3.8453 - coeff_determination: -5.4391 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 23/50
# 669/669 [==============================] - 0s 163us/step - loss: 3.8453 - coeff_determination: -5.9718 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 24/50
# 669/669 [==============================] - 0s 159us/step - loss: 3.8453 - coeff_determination: -4.8776 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 25/50
# 669/669 [==============================] - 0s 155us/step - loss: 3.8453 - coeff_determination: -5.2580 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 26/50
# 669/669 [==============================] - 0s 152us/step - loss: 3.8453 - coeff_determination: -4.6739 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 27/50
# 669/669 [==============================] - 0s 152us/step - loss: 3.8453 - coeff_determination: -4.6528 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 28/50
# 669/669 [==============================] - 0s 164us/step - loss: 3.8453 - coeff_determination: -5.5690 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 29/50
# 669/669 [==============================] - 0s 161us/step - loss: 3.8453 - coeff_determination: -7.9847 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 30/50
# 669/669 [==============================] - 0s 158us/step - loss: 3.8453 - coeff_determination: -5.7840 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 31/50
# 669/669 [==============================] - 0s 156us/step - loss: 3.8453 - coeff_determination: -5.1842 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 32/50
# 669/669 [==============================] - 0s 152us/step - loss: 3.8453 - coeff_determination: -5.6989 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 33/50
# 669/669 [==============================] - 0s 154us/step - loss: 3.8453 - coeff_determination: -5.4372 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 34/50
# 669/669 [==============================] - 0s 163us/step - loss: 3.8453 - coeff_determination: -4.5631 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 35/50
# 669/669 [==============================] - 0s 165us/step - loss: 3.8453 - coeff_determination: -4.9135 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 36/50
# 669/669 [==============================] - 0s 161us/step - loss: 3.8453 - coeff_determination: -5.3816 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 37/50
# 669/669 [==============================] - 0s 153us/step - loss: 3.8453 - coeff_determination: -5.1953 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 38/50
# 669/669 [==============================] - 0s 153us/step - loss: 3.8453 - coeff_determination: -4.5349 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 39/50
# 669/669 [==============================] - 0s 171us/step - loss: 3.8453 - coeff_determination: -5.0084 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 40/50
# 669/669 [==============================] - 0s 165us/step - loss: 3.8453 - coeff_determination: -4.9583 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 41/50
# 669/669 [==============================] - 0s 154us/step - loss: 3.8453 - coeff_determination: -6.0223 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 42/50
# 669/669 [==============================] - 0s 152us/step - loss: 3.8453 - coeff_determination: -5.1858 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 43/50
# 669/669 [==============================] - 0s 153us/step - loss: 3.8453 - coeff_determination: -5.3109 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 44/50
# 669/669 [==============================] - 0s 167us/step - loss: 3.8453 - coeff_determination: -4.7712 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 45/50
# 669/669 [==============================] - 0s 163us/step - loss: 3.8453 - coeff_determination: -5.1280 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 46/50
# 669/669 [==============================] - 0s 165us/step - loss: 3.8453 - coeff_determination: -4.6558 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 47/50
# 669/669 [==============================] - 0s 165us/step - loss: 3.8453 - coeff_determination: -5.4593 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 48/50
# 669/669 [==============================] - 0s 151us/step - loss: 3.8453 - coeff_determination: -4.5278 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 49/50
# 669/669 [==============================] - 0s 160us/step - loss: 3.8453 - coeff_determination: -4.9176 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 50/50
# 669/669 [==============================] - 0s 159us/step - loss: 3.8453 - coeff_determination: -5.1494 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# 1853/1853 [==============================] - 0s 22us/step
# -3.55609436223009
# running iteration 3
# create input layer with activation of tanh
# create hidden layer 0 of type tanh
# create output layer with activation of linear
# Train on 669 samples, validate on 331 samples
# Epoch 1/50
# 669/669 [==============================] - 1s 2ms/step - loss: 1.0269 - coeff_determination: -0.4224 - val_loss: 0.6651 - val_coeff_determination: -7151.9007
# Epoch 2/50
# 669/669 [==============================] - 0s 166us/step - loss: 0.6218 - coeff_determination: 0.0341 - val_loss: 0.5758 - val_coeff_determination: -2548.4040
# Epoch 3/50
# 669/669 [==============================] - 0s 165us/step - loss: 0.5854 - coeff_determination: 0.1568 - val_loss: 0.5649 - val_coeff_determination: -1213.5183
# Epoch 4/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.5716 - coeff_determination: 0.2433 - val_loss: 0.5483 - val_coeff_determination: -1753.2488
# Epoch 5/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.5538 - coeff_determination: 0.2163 - val_loss: 0.5297 - val_coeff_determination: -860.2132
# Epoch 6/50
# 669/669 [==============================] - 0s 168us/step - loss: 0.5379 - coeff_determination: 0.2444 - val_loss: 0.5129 - val_coeff_determination: -1155.6880
# Epoch 7/50
# 669/669 [==============================] - 0s 161us/step - loss: 0.5098 - coeff_determination: 0.3122 - val_loss: 0.4912 - val_coeff_determination: -1516.6769
# Epoch 8/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.4801 - coeff_determination: 0.3168 - val_loss: 0.4627 - val_coeff_determination: -1495.7967
# Epoch 9/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.4463 - coeff_determination: 0.3692 - val_loss: 0.4218 - val_coeff_determination: -1196.0279
# Epoch 10/50
# 669/669 [==============================] - 0s 166us/step - loss: 0.4080 - coeff_determination: 0.4186 - val_loss: 0.3837 - val_coeff_determination: -560.0365
# Epoch 11/50
# 669/669 [==============================] - 0s 164us/step - loss: 0.3740 - coeff_determination: 0.4154 - val_loss: 0.3533 - val_coeff_determination: -670.9143
# Epoch 12/50
# 669/669 [==============================] - 0s 160us/step - loss: 0.3390 - coeff_determination: 0.5588 - val_loss: 0.3171 - val_coeff_determination: -450.4916
# Epoch 13/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.3096 - coeff_determination: 0.5685 - val_loss: 0.2935 - val_coeff_determination: -472.2139
# Epoch 14/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.2829 - coeff_determination: 0.5944 - val_loss: 0.2661 - val_coeff_determination: -253.2067
# Epoch 15/50
# 669/669 [==============================] - 0s 167us/step - loss: 0.2609 - coeff_determination: 0.6522 - val_loss: 0.2499 - val_coeff_determination: -6.3161
# Epoch 16/50
# 669/669 [==============================] - 0s 162us/step - loss: 0.2458 - coeff_determination: 0.6125 - val_loss: 0.2346 - val_coeff_determination: -252.8187
# Epoch 17/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.2334 - coeff_determination: 0.6855 - val_loss: 0.2221 - val_coeff_determination: -306.5506
# Epoch 18/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.2238 - coeff_determination: 0.6616 - val_loss: 0.2211 - val_coeff_determination: -107.1987
# Epoch 19/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.2167 - coeff_determination: 0.6827 - val_loss: 0.2193 - val_coeff_determination: -700.6654
# Epoch 20/50
# 669/669 [==============================] - 0s 169us/step - loss: 0.2110 - coeff_determination: 0.7045 - val_loss: 0.2059 - val_coeff_determination: -192.8484
# Epoch 21/50
# 669/669 [==============================] - 0s 165us/step - loss: 0.2036 - coeff_determination: 0.6728 - val_loss: 0.1983 - val_coeff_determination: -214.7417
# Epoch 22/50
# 669/669 [==============================] - 0s 158us/step - loss: 0.1987 - coeff_determination: 0.7119 - val_loss: 0.1946 - val_coeff_determination: -568.0163
# Epoch 23/50
# 669/669 [==============================] - 0s 159us/step - loss: 0.1941 - coeff_determination: 0.7323 - val_loss: 0.1893 - val_coeff_determination: -510.0204
# Epoch 24/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.1883 - coeff_determination: 0.7051 - val_loss: 0.1830 - val_coeff_determination: -228.9674
# Epoch 25/50
# 669/669 [==============================] - 0s 155us/step - loss: 0.1819 - coeff_determination: 0.7223 - val_loss: 0.1771 - val_coeff_determination: -110.4846
# Epoch 26/50
# 669/669 [==============================] - 0s 168us/step - loss: 0.1755 - coeff_determination: 0.7194 - val_loss: 0.1716 - val_coeff_determination: -702.7484
# Epoch 27/50
# 669/669 [==============================] - 0s 165us/step - loss: 0.1729 - coeff_determination: 0.7550 - val_loss: 0.1649 - val_coeff_determination: -386.6826
# Epoch 28/50
# 669/669 [==============================] - 0s 160us/step - loss: 0.1665 - coeff_determination: 0.7632 - val_loss: 0.1605 - val_coeff_determination: -103.5830
# Epoch 29/50
# 669/669 [==============================] - 0s 157us/step - loss: 0.1572 - coeff_determination: 0.7746 - val_loss: 0.1531 - val_coeff_determination: -955.6981
# Epoch 30/50
# 669/669 [==============================] - 0s 163us/step - loss: 0.1505 - coeff_determination: 0.7792 - val_loss: 0.1447 - val_coeff_determination: -385.2810
# Epoch 31/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.1467 - coeff_determination: 0.7853 - val_loss: 0.1373 - val_coeff_determination: -557.7152
# Epoch 32/50
# 669/669 [==============================] - 0s 167us/step - loss: 0.1384 - coeff_determination: 0.7988 - val_loss: 0.1381 - val_coeff_determination: -600.0554
# Epoch 33/50
# 669/669 [==============================] - 0s 163us/step - loss: 0.1340 - coeff_determination: 0.8148 - val_loss: 0.1331 - val_coeff_determination: -1588.8994
# Epoch 34/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.1296 - coeff_determination: 0.8103 - val_loss: 0.1233 - val_coeff_determination: -1255.0383
# Epoch 35/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.1246 - coeff_determination: 0.8197 - val_loss: 0.1200 - val_coeff_determination: -1617.5115
# Epoch 36/50
# 669/669 [==============================] - 0s 170us/step - loss: 0.1226 - coeff_determination: 0.8098 - val_loss: 0.1124 - val_coeff_determination: -1790.5642
# Epoch 37/50
# 669/669 [==============================] - 0s 163us/step - loss: 0.1180 - coeff_determination: 0.8153 - val_loss: 0.1094 - val_coeff_determination: -959.1431
# Epoch 38/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.1148 - coeff_determination: 0.8111 - val_loss: 0.1052 - val_coeff_determination: -1286.2511
# Epoch 39/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.1134 - coeff_determination: 0.8297 - val_loss: 0.1006 - val_coeff_determination: -1932.2807
# Epoch 40/50
# 669/669 [==============================] - 0s 167us/step - loss: 0.1097 - coeff_determination: 0.8291 - val_loss: 0.0986 - val_coeff_determination: -1382.5489
# Epoch 41/50
# 669/669 [==============================] - 0s 164us/step - loss: 0.1086 - coeff_determination: 0.8350 - val_loss: 0.1034 - val_coeff_determination: -986.4005
# Epoch 42/50
# 669/669 [==============================] - 0s 162us/step - loss: 0.1073 - coeff_determination: 0.8537 - val_loss: 0.0979 - val_coeff_determination: -1358.8547
# Epoch 43/50
# 669/669 [==============================] - 0s 159us/step - loss: 0.1034 - coeff_determination: 0.8361 - val_loss: 0.0922 - val_coeff_determination: -1308.7170
# Epoch 44/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.1029 - coeff_determination: 0.8197 - val_loss: 0.0977 - val_coeff_determination: -295.1014
# Epoch 45/50
# 669/669 [==============================] - 0s 156us/step - loss: 0.1003 - coeff_determination: 0.8441 - val_loss: 0.0884 - val_coeff_determination: -1363.7309
# Epoch 46/50
# 669/669 [==============================] - 0s 153us/step - loss: 0.0986 - coeff_determination: 0.8479 - val_loss: 0.0862 - val_coeff_determination: -707.8584
# Epoch 47/50
# 669/669 [==============================] - 0s 159us/step - loss: 0.0964 - coeff_determination: 0.8567 - val_loss: 0.0824 - val_coeff_determination: -987.8241
# Epoch 48/50
# 669/669 [==============================] - 0s 154us/step - loss: 0.0942 - coeff_determination: 0.8675 - val_loss: 0.0806 - val_coeff_determination: -861.2254
# Epoch 49/50
# 669/669 [==============================] - 0s 166us/step - loss: 0.0921 - coeff_determination: 0.8672 - val_loss: 0.0842 - val_coeff_determination: -315.8228
# Epoch 50/50
# 669/669 [==============================] - 0s 165us/step - loss: 0.0892 - coeff_determination: 0.8568 - val_loss: 0.0776 - val_coeff_determination: -1334.5464
# 1853/1853 [==============================] - 0s 23us/step
# 0.9063573003587244
# running iteration 4
# create input layer with activation of softmax
# create hidden layer 0 of type tanh
# create output layer with activation of tanh
# Train on 669 samples, validate on 331 samples
# Epoch 1/50
# 669/669 [==============================] - 1s 2ms/step - loss: 0.9692 - coeff_determination: -0.2758 - val_loss: 0.9205 - val_coeff_determination: -18021.8170
# Epoch 2/50
# 669/669 [==============================] - 0s 169us/step - loss: 0.8566 - coeff_determination: -0.1277 - val_loss: 0.8730 - val_coeff_determination: -14345.8893
# Epoch 3/50
# 669/669 [==============================] - 0s 168us/step - loss: 0.7993 - coeff_determination: -0.0536 - val_loss: 0.7939 - val_coeff_determination: -13632.3677
# Epoch 4/50
# 669/669 [==============================] - 0s 165us/step - loss: 0.7129 - coeff_determination: 0.1323 - val_loss: 0.6777 - val_coeff_determination: -12060.0390
# Epoch 5/50
# 669/669 [==============================] - 0s 157us/step - loss: 0.6042 - coeff_determination: 0.2533 - val_loss: 0.5679 - val_coeff_determination: -9309.7195
# Epoch 6/50
# 669/669 [==============================] - 0s 166us/step - loss: 0.5099 - coeff_determination: 0.2414 - val_loss: 0.4855 - val_coeff_determination: -7061.3724
# Epoch 7/50
# 669/669 [==============================] - 0s 178us/step - loss: 0.4449 - coeff_determination: 0.4084 - val_loss: 0.4180 - val_coeff_determination: -6368.4204
# Epoch 8/50
# 669/669 [==============================] - 0s 176us/step - loss: 0.4021 - coeff_determination: 0.4254 - val_loss: 0.3845 - val_coeff_determination: -5501.2747
# Epoch 9/50
# 669/669 [==============================] - 0s 163us/step - loss: 0.3759 - coeff_determination: 0.4685 - val_loss: 0.3631 - val_coeff_determination: -5114.7801
# Epoch 10/50
# 669/669 [==============================] - 0s 172us/step - loss: 0.3588 - coeff_determination: 0.4931 - val_loss: 0.3489 - val_coeff_determination: -4885.0795
# Epoch 11/50
# 669/669 [==============================] - 0s 249us/step - loss: 0.3481 - coeff_determination: 0.4232 - val_loss: 0.3367 - val_coeff_determination: -4774.8174
# Epoch 12/50
# 669/669 [==============================] - 0s 264us/step - loss: 0.3403 - coeff_determination: 0.5285 - val_loss: 0.3287 - val_coeff_determination: -4696.6881
# Epoch 13/50
# 669/669 [==============================] - 0s 198us/step - loss: 0.3351 - coeff_determination: 0.4678 - val_loss: 0.3267 - val_coeff_determination: -4625.7790
# Epoch 14/50
# 669/669 [==============================] - 0s 225us/step - loss: 0.3319 - coeff_determination: 0.5289 - val_loss: 0.3243 - val_coeff_determination: -4581.5276
# Epoch 15/50
# 669/669 [==============================] - 0s 251us/step - loss: 0.3272 - coeff_determination: 0.5381 - val_loss: 0.3202 - val_coeff_determination: -4561.7826
# Epoch 16/50
# 669/669 [==============================] - 0s 177us/step - loss: 0.3258 - coeff_determination: 0.5419 - val_loss: 0.3130 - val_coeff_determination: -4556.3408
# Epoch 17/50
# 669/669 [==============================] - 0s 174us/step - loss: 0.3218 - coeff_determination: 0.5527 - val_loss: 0.3126 - val_coeff_determination: -4535.9705
# Epoch 18/50
# 669/669 [==============================] - 0s 178us/step - loss: 0.3201 - coeff_determination: 0.5125 - val_loss: 0.3098 - val_coeff_determination: -4525.2929
# Epoch 19/50
# 669/669 [==============================] - 0s 164us/step - loss: 0.3188 - coeff_determination: 0.4668 - val_loss: 0.3087 - val_coeff_determination: -4517.4218
# Epoch 20/50
# 669/669 [==============================] - 0s 171us/step - loss: 0.3165 - coeff_determination: 0.5447 - val_loss: 0.3077 - val_coeff_determination: -4507.6921
# Epoch 21/50
# 669/669 [==============================] - 0s 230us/step - loss: 0.3151 - coeff_determination: 0.5065 - val_loss: 0.3041 - val_coeff_determination: -4506.9439
# Epoch 22/50
# 669/669 [==============================] - 0s 220us/step - loss: 0.3144 - coeff_determination: 0.5763 - val_loss: 0.3032 - val_coeff_determination: -4502.2645
# Epoch 23/50
# 669/669 [==============================] - 0s 205us/step - loss: 0.3136 - coeff_determination: 0.5277 - val_loss: 0.3012 - val_coeff_determination: -4501.8729
# Epoch 24/50
# 669/669 [==============================] - 0s 209us/step - loss: 0.3116 - coeff_determination: 0.5824 - val_loss: 0.3014 - val_coeff_determination: -4493.6862
# Epoch 25/50
# 669/669 [==============================] - 0s 209us/step - loss: 0.3109 - coeff_determination: 0.5143 - val_loss: 0.3001 - val_coeff_determination: -4493.9455
# Epoch 26/50
# 669/669 [==============================] - 0s 195us/step - loss: 0.3087 - coeff_determination: 0.5766 - val_loss: 0.2977 - val_coeff_determination: -4495.3886
# Epoch 27/50
# 669/669 [==============================] - 0s 234us/step - loss: 0.3076 - coeff_determination: 0.5689 - val_loss: 0.2962 - val_coeff_determination: -4495.5480
# Epoch 28/50
# 669/669 [==============================] - 0s 198us/step - loss: 0.3065 - coeff_determination: 0.5655 - val_loss: 0.2955 - val_coeff_determination: -4492.4158
# Epoch 29/50
# 669/669 [==============================] - 0s 194us/step - loss: 0.3056 - coeff_determination: 0.5656 - val_loss: 0.2932 - val_coeff_determination: -4493.9995
# Epoch 30/50
# 669/669 [==============================] - 0s 215us/step - loss: 0.3039 - coeff_determination: 0.5550 - val_loss: 0.2915 - val_coeff_determination: -4508.1810
# Epoch 31/50
# 669/669 [==============================] - 0s 207us/step - loss: 0.3040 - coeff_determination: 0.5493 - val_loss: 0.2956 - val_coeff_determination: -4484.1260
# Epoch 32/50
# 669/669 [==============================] - 0s 203us/step - loss: 0.3038 - coeff_determination: 0.5572 - val_loss: 0.2937 - val_coeff_determination: -4482.7999
# Epoch 33/50
# 669/669 [==============================] - 0s 164us/step - loss: 0.3017 - coeff_determination: 0.5942 - val_loss: 0.2910 - val_coeff_determination: -4487.7719
# Epoch 34/50
# 669/669 [==============================] - 0s 165us/step - loss: 0.3011 - coeff_determination: 0.5700 - val_loss: 0.2891 - val_coeff_determination: -4490.4739
# Epoch 35/50
# 669/669 [==============================] - 0s 161us/step - loss: 0.3002 - coeff_determination: 0.5806 - val_loss: 0.2888 - val_coeff_determination: -4489.5819
# Epoch 36/50
# 669/669 [==============================] - 0s 162us/step - loss: 0.2989 - coeff_determination: 0.5758 - val_loss: 0.2902 - val_coeff_determination: -4484.2294
# Epoch 37/50
# 669/669 [==============================] - 0s 168us/step - loss: 0.2989 - coeff_determination: 0.5656 - val_loss: 0.2861 - val_coeff_determination: -4494.7905
# Epoch 38/50
# 669/669 [==============================] - 0s 181us/step - loss: 0.2975 - coeff_determination: 0.5345 - val_loss: 0.2869 - val_coeff_determination: -4487.7158
# Epoch 39/50
# 669/669 [==============================] - 0s 212us/step - loss: 0.2972 - coeff_determination: 0.5530 - val_loss: 0.2879 - val_coeff_determination: -4483.8332
# Epoch 40/50
# 669/669 [==============================] - 0s 202us/step - loss: 0.2967 - coeff_determination: 0.5754 - val_loss: 0.2849 - val_coeff_determination: -4490.2475
# Epoch 41/50
# 669/669 [==============================] - 0s 201us/step - loss: 0.2955 - coeff_determination: 0.6040 - val_loss: 0.2836 - val_coeff_determination: -4491.0220
# Epoch 42/50
# 669/669 [==============================] - 0s 195us/step - loss: 0.2953 - coeff_determination: 0.5838 - val_loss: 0.2845 - val_coeff_determination: -4488.5959
# Epoch 43/50
# 669/669 [==============================] - 0s 192us/step - loss: 0.2939 - coeff_determination: 0.5416 - val_loss: 0.2817 - val_coeff_determination: -4497.0639
# Epoch 44/50
# 669/669 [==============================] - 0s 208us/step - loss: 0.2935 - coeff_determination: 0.5941 - val_loss: 0.2845 - val_coeff_determination: -4482.6632
# Epoch 45/50
# 669/669 [==============================] - 0s 206us/step - loss: 0.2929 - coeff_determination: 0.5576 - val_loss: 0.2839 - val_coeff_determination: -4481.9634
# Epoch 46/50
# 669/669 [==============================] - 0s 179us/step - loss: 0.2920 - coeff_determination: 0.5332 - val_loss: 0.2805 - val_coeff_determination: -4490.6878
# Epoch 47/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.2918 - coeff_determination: 0.5774 - val_loss: 0.2802 - val_coeff_determination: -4489.2001
# Epoch 48/50
# 669/669 [==============================] - 0s 212us/step - loss: 0.2909 - coeff_determination: 0.5794 - val_loss: 0.2791 - val_coeff_determination: -4494.6598
# Epoch 49/50
# 669/669 [==============================] - 0s 210us/step - loss: 0.2907 - coeff_determination: 0.5096 - val_loss: 0.2799 - val_coeff_determination: -4483.7233
# Epoch 50/50
# 669/669 [==============================] - 0s 198us/step - loss: 0.2902 - coeff_determination: 0.5883 - val_loss: 0.2786 - val_coeff_determination: -4488.3974
# 1853/1853 [==============================] - 0s 27us/step
# 0.6458199103330189
# running iteration 5
# create input layer with activation of softmax
# create hidden layer 0 of type tanh
# create output layer with activation of softmax
# Train on 669 samples, validate on 331 samples
# Epoch 1/50
# 669/669 [==============================] - 1s 2ms/step - loss: 3.8453 - coeff_determination: -5.0178 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 2/50
# 669/669 [==============================] - 0s 212us/step - loss: 3.8453 - coeff_determination: -5.1186 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 3/50
# 669/669 [==============================] - 0s 174us/step - loss: 3.8453 - coeff_determination: -6.2158 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 4/50
# 669/669 [==============================] - 0s 216us/step - loss: 3.8453 - coeff_determination: -4.7003 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 5/50
# 669/669 [==============================] - 0s 210us/step - loss: 3.8453 - coeff_determination: -5.2858 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 6/50
# 669/669 [==============================] - 0s 242us/step - loss: 3.8453 - coeff_determination: -5.1693 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 7/50
# 669/669 [==============================] - 0s 237us/step - loss: 3.8453 - coeff_determination: -4.9016 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 8/50
# 669/669 [==============================] - 0s 230us/step - loss: 3.8453 - coeff_determination: -5.4410 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 9/50
# 669/669 [==============================] - 0s 215us/step - loss: 3.8453 - coeff_determination: -4.9371 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 10/50
# 669/669 [==============================] - 0s 210us/step - loss: 3.8453 - coeff_determination: -4.7907 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 11/50
# 669/669 [==============================] - 0s 212us/step - loss: 3.8453 - coeff_determination: -4.7428 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 12/50
# 669/669 [==============================] - 0s 209us/step - loss: 3.8453 - coeff_determination: -5.0901 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 13/50
# 669/669 [==============================] - 0s 208us/step - loss: 3.8453 - coeff_determination: -4.4754 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 14/50
# 669/669 [==============================] - 0s 176us/step - loss: 3.8453 - coeff_determination: -6.4299 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 15/50
# 669/669 [==============================] - 0s 169us/step - loss: 3.8453 - coeff_determination: -4.7155 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 16/50
# 669/669 [==============================] - 0s 172us/step - loss: 3.8453 - coeff_determination: -4.9046 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 17/50
# 669/669 [==============================] - 0s 171us/step - loss: 3.8453 - coeff_determination: -5.1761 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 18/50
# 669/669 [==============================] - 0s 216us/step - loss: 3.8453 - coeff_determination: -4.9331 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 19/50
# 669/669 [==============================] - 0s 214us/step - loss: 3.8453 - coeff_determination: -4.8999 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 20/50
# 669/669 [==============================] - 0s 210us/step - loss: 3.8453 - coeff_determination: -4.2977 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 21/50
# 669/669 [==============================] - 0s 219us/step - loss: 3.8453 - coeff_determination: -6.2228 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 22/50
# 669/669 [==============================] - 0s 221us/step - loss: 3.8453 - coeff_determination: -5.2832 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 23/50
# 669/669 [==============================] - 0s 234us/step - loss: 3.8453 - coeff_determination: -5.1649 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 24/50
# 669/669 [==============================] - 0s 244us/step - loss: 3.8453 - coeff_determination: -5.4773 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 25/50
# 669/669 [==============================] - 0s 256us/step - loss: 3.8453 - coeff_determination: -4.7982 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 26/50
# 669/669 [==============================] - 0s 245us/step - loss: 3.8453 - coeff_determination: -4.5166 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 27/50
# 669/669 [==============================] - 0s 169us/step - loss: 3.8453 - coeff_determination: -5.0255 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 28/50
# 669/669 [==============================] - 0s 197us/step - loss: 3.8453 - coeff_determination: -4.6618 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 29/50
# 669/669 [==============================] - 0s 251us/step - loss: 3.8453 - coeff_determination: -5.7049 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 30/50
# 669/669 [==============================] - 0s 255us/step - loss: 3.8453 - coeff_determination: -5.2378 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 31/50
# 669/669 [==============================] - 0s 252us/step - loss: 3.8453 - coeff_determination: -5.6822 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 32/50
# 669/669 [==============================] - 0s 176us/step - loss: 3.8453 - coeff_determination: -5.1517 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 33/50
# 669/669 [==============================] - 0s 175us/step - loss: 3.8453 - coeff_determination: -6.3244 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 34/50
# 669/669 [==============================] - 0s 177us/step - loss: 3.8453 - coeff_determination: -4.9941 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 35/50
# 669/669 [==============================] - 0s 162us/step - loss: 3.8453 - coeff_determination: -5.2167 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 36/50
# 669/669 [==============================] - 0s 179us/step - loss: 3.8453 - coeff_determination: -5.3353 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 37/50
# 669/669 [==============================] - 0s 188us/step - loss: 3.8453 - coeff_determination: -4.7760 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 38/50
# 669/669 [==============================] - 0s 170us/step - loss: 3.8453 - coeff_determination: -4.9818 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 39/50
# 669/669 [==============================] - 0s 183us/step - loss: 3.8453 - coeff_determination: -5.4497 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 40/50
# 669/669 [==============================] - 0s 172us/step - loss: 3.8453 - coeff_determination: -5.5434 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 41/50
# 669/669 [==============================] - 0s 161us/step - loss: 3.8453 - coeff_determination: -5.5400 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 42/50
# 669/669 [==============================] - 0s 213us/step - loss: 3.8453 - coeff_determination: -5.3447 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 43/50
# 669/669 [==============================] - 0s 217us/step - loss: 3.8453 - coeff_determination: -4.9997 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 44/50
# 669/669 [==============================] - 0s 176us/step - loss: 3.8453 - coeff_determination: -5.1356 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 45/50
# 669/669 [==============================] - 0s 167us/step - loss: 3.8453 - coeff_determination: -4.7297 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 46/50
# 669/669 [==============================] - 0s 194us/step - loss: 3.8453 - coeff_determination: -4.4436 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 47/50
# 669/669 [==============================] - 0s 211us/step - loss: 3.8453 - coeff_determination: -4.9506 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 48/50
# 669/669 [==============================] - 0s 203us/step - loss: 3.8453 - coeff_determination: -5.9715 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 49/50
# 669/669 [==============================] - 0s 174us/step - loss: 3.8453 - coeff_determination: -5.1354 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 50/50
# 669/669 [==============================] - 0s 170us/step - loss: 3.8453 - coeff_determination: -5.9411 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# 1853/1853 [==============================] - 0s 27us/step
# -3.55609436223009
# running iteration 6
# create input layer with activation of softmax
# create hidden layer 0 of type tanh
# create output layer with activation of linear
# Train on 669 samples, validate on 331 samples
# Epoch 1/50
# 669/669 [==============================] - 1s 2ms/step - loss: 1.0430 - coeff_determination: -0.3138 - val_loss: 0.9498 - val_coeff_determination: -17114.0992
# Epoch 2/50
# 669/669 [==============================] - 0s 221us/step - loss: 0.8723 - coeff_determination: -0.0637 - val_loss: 0.8916 - val_coeff_determination: -11241.1415
# Epoch 3/50
# 669/669 [==============================] - 0s 216us/step - loss: 0.8118 - coeff_determination: -0.0067 - val_loss: 0.8119 - val_coeff_determination: -12125.0760
# Epoch 4/50
# 669/669 [==============================] - 0s 193us/step - loss: 0.7419 - coeff_determination: 0.0779 - val_loss: 0.7215 - val_coeff_determination: -9819.3176
# Epoch 5/50
# 669/669 [==============================] - 0s 180us/step - loss: 0.6641 - coeff_determination: 0.1483 - val_loss: 0.6458 - val_coeff_determination: -7078.6411
# Epoch 6/50
# 669/669 [==============================] - 0s 216us/step - loss: 0.6029 - coeff_determination: 0.2215 - val_loss: 0.5806 - val_coeff_determination: -6107.0741
# Epoch 7/50
# 669/669 [==============================] - 0s 209us/step - loss: 0.5589 - coeff_determination: 0.2492 - val_loss: 0.5381 - val_coeff_determination: -3326.3647
# Epoch 8/50
# 669/669 [==============================] - 0s 180us/step - loss: 0.5279 - coeff_determination: 0.2911 - val_loss: 0.5132 - val_coeff_determination: -2054.6529
# Epoch 9/50
# 669/669 [==============================] - 0s 168us/step - loss: 0.5062 - coeff_determination: 0.2768 - val_loss: 0.4806 - val_coeff_determination: -2795.8361
# Epoch 10/50
# 669/669 [==============================] - 0s 168us/step - loss: 0.4829 - coeff_determination: 0.2596 - val_loss: 0.4606 - val_coeff_determination: -1634.7830
# Epoch 11/50
# 669/669 [==============================] - 0s 170us/step - loss: 0.4560 - coeff_determination: 0.3052 - val_loss: 0.4339 - val_coeff_determination: -2264.9549
# Epoch 12/50
# 669/669 [==============================] - 0s 182us/step - loss: 0.4304 - coeff_determination: 0.3058 - val_loss: 0.4074 - val_coeff_determination: -1204.0069
# Epoch 13/50
# 669/669 [==============================] - 0s 202us/step - loss: 0.3995 - coeff_determination: 0.4508 - val_loss: 0.3826 - val_coeff_determination: -681.5114
# Epoch 14/50
# 669/669 [==============================] - 0s 182us/step - loss: 0.3659 - coeff_determination: 0.4489 - val_loss: 0.3475 - val_coeff_determination: -418.4795
# Epoch 15/50
# 669/669 [==============================] - 0s 172us/step - loss: 0.3278 - coeff_determination: 0.4703 - val_loss: 0.3031 - val_coeff_determination: -646.7079
# Epoch 16/50
# 669/669 [==============================] - 0s 169us/step - loss: 0.2824 - coeff_determination: 0.5615 - val_loss: 0.2616 - val_coeff_determination: -1529.9345
# Epoch 17/50
# 669/669 [==============================] - 0s 169us/step - loss: 0.2407 - coeff_determination: 0.6349 - val_loss: 0.2184 - val_coeff_determination: -833.8908
# Epoch 18/50
# 669/669 [==============================] - 0s 169us/step - loss: 0.1979 - coeff_determination: 0.7211 - val_loss: 0.1822 - val_coeff_determination: -750.8378
# Epoch 19/50
# 669/669 [==============================] - 0s 168us/step - loss: 0.1631 - coeff_determination: 0.7525 - val_loss: 0.1516 - val_coeff_determination: -672.7246
# Epoch 20/50
# 669/669 [==============================] - 0s 170us/step - loss: 0.1384 - coeff_determination: 0.7860 - val_loss: 0.1309 - val_coeff_determination: -570.6780
# Epoch 21/50
# ...
# Epoch 11/50
# 669/669 [==============================] - 0s 211us/step - loss: 3.8453 - coeff_determination: -5.0226 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 12/50
# 669/669 [==============================] - 0s 209us/step - loss: 3.8453 - coeff_determination: -6.2784 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 13/50
# 669/669 [==============================] - 0s 212us/step - loss: 3.8453 - coeff_determination: -4.8313 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 14/50
# 669/669 [==============================] - 0s 211us/step - loss: 3.8453 - coeff_determination: -5.0758 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 15/50
# 669/669 [==============================] - 0s 214us/step - loss: 3.8453 - coeff_determination: -5.9445 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 16/50
# 669/669 [==============================] - 0s 210us/step - loss: 3.8453 - coeff_determination: -4.5302 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 17/50
# 669/669 [==============================] - 0s 211us/step - loss: 3.8453 - coeff_determination: -5.5008 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 18/50
# 669/669 [==============================] - 0s 209us/step - loss: 3.8453 - coeff_determination: -6.3452 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 19/50
# 669/669 [==============================] - 0s 214us/step - loss: 3.8453 - coeff_determination: -5.2840 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 20/50
# 669/669 [==============================] - 0s 212us/step - loss: 3.8453 - coeff_determination: -5.1240 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 21/50
# 669/669 [==============================] - 0s 212us/step - loss: 3.8453 - coeff_determination: -5.1195 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 22/50
# 669/669 [==============================] - 0s 211us/step - loss: 3.8453 - coeff_determination: -6.2940 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 23/50
# 669/669 [==============================] - 0s 209us/step - loss: 3.8453 - coeff_determination: -5.4243 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 24/50
# 669/669 [==============================] - 0s 209us/step - loss: 3.8453 - coeff_determination: -5.6653 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 25/50
# 669/669 [==============================] - 0s 208us/step - loss: 3.8453 - coeff_determination: -5.2288 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 26/50
# 669/669 [==============================] - 0s 211us/step - loss: 3.8453 - coeff_determination: -4.7436 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 27/50
# 669/669 [==============================] - 0s 211us/step - loss: 3.8453 - coeff_determination: -4.4618 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 28/50
# 669/669 [==============================] - 0s 211us/step - loss: 3.8453 - coeff_determination: -5.7418 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 29/50
# 669/669 [==============================] - 0s 213us/step - loss: 3.8453 - coeff_determination: -4.9846 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 30/50
# 669/669 [==============================] - 0s 211us/step - loss: 3.8453 - coeff_determination: -4.5848 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 31/50
# 669/669 [==============================] - 0s 208us/step - loss: 3.8453 - coeff_determination: -5.3589 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 32/50
# 669/669 [==============================] - 0s 209us/step - loss: 3.8453 - coeff_determination: -4.5688 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 33/50
# 669/669 [==============================] - 0s 210us/step - loss: 3.8453 - coeff_determination: -5.0780 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 34/50
# 669/669 [==============================] - 0s 209us/step - loss: 3.8453 - coeff_determination: -5.1589 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 35/50
# 669/669 [==============================] - 0s 213us/step - loss: 3.8453 - coeff_determination: -5.1565 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 36/50
# 669/669 [==============================] - 0s 210us/step - loss: 3.8453 - coeff_determination: -5.1811 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 37/50
# 669/669 [==============================] - 0s 213us/step - loss: 3.8453 - coeff_determination: -5.7538 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 38/50
# 669/669 [==============================] - 0s 210us/step - loss: 3.8453 - coeff_determination: -4.9614 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 39/50
# 669/669 [==============================] - 0s 213us/step - loss: 3.8453 - coeff_determination: -5.0824 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 40/50
# 669/669 [==============================] - 0s 209us/step - loss: 3.8453 - coeff_determination: -4.7666 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 41/50
# 669/669 [==============================] - 0s 213us/step - loss: 3.8453 - coeff_determination: -4.7515 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 42/50
# 669/669 [==============================] - 0s 210us/step - loss: 3.8453 - coeff_determination: -6.8932 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 43/50
# 669/669 [==============================] - 0s 216us/step - loss: 3.8453 - coeff_determination: -4.6403 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 44/50
# 669/669 [==============================] - 0s 214us/step - loss: 3.8453 - coeff_determination: -4.8286 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 45/50
# 669/669 [==============================] - 0s 208us/step - loss: 3.8453 - coeff_determination: -6.0366 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 46/50
# 669/669 [==============================] - 0s 208us/step - loss: 3.8453 - coeff_determination: -5.3162 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 47/50
# 669/669 [==============================] - 0s 208us/step - loss: 3.8453 - coeff_determination: -5.3552 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 48/50
# 669/669 [==============================] - 0s 209us/step - loss: 3.8453 - coeff_determination: -4.3664 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 49/50
# 669/669 [==============================] - 0s 211us/step - loss: 3.8453 - coeff_determination: -5.7681 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# Epoch 50/50
# 669/669 [==============================] - 0s 209us/step - loss: 3.8453 - coeff_determination: -4.6696 - val_loss: 3.7748 - val_coeff_determination: -171539.1360
# 1853/1853 [==============================] - 0s 31us/step
# -3.55609436223009
# running iteration 27
# create input layer with activation of linear
# create hidden layer 0 of type linear
# create output layer with activation of linear
# Train on 669 samples, validate on 331 samples
# Epoch 1/50
# 669/669 [==============================] - 2s 3ms/step - loss: 1.0160 - coeff_determination: -0.3836 - val_loss: 0.6540 - val_coeff_determination: -11549.3225
# Epoch 2/50
# 669/669 [==============================] - 0s 235us/step - loss: 0.6321 - coeff_determination: 0.1658 - val_loss: 0.6128 - val_coeff_determination: -4320.1816
# Epoch 3/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6318 - coeff_determination: 0.0898 - val_loss: 0.6158 - val_coeff_determination: -5340.6609
# Epoch 4/50
# 669/669 [==============================] - 0s 217us/step - loss: 0.6314 - coeff_determination: 0.0952 - val_loss: 0.6171 - val_coeff_determination: -4280.1280
# Epoch 5/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6325 - coeff_determination: 0.1090 - val_loss: 0.6240 - val_coeff_determination: -4484.7581
# Epoch 6/50
# 669/669 [==============================] - 0s 213us/step - loss: 0.6337 - coeff_determination: 0.1561 - val_loss: 0.6161 - val_coeff_determination: -5610.2734
# Epoch 7/50
# 669/669 [==============================] - 0s 212us/step - loss: 0.6316 - coeff_determination: 0.0795 - val_loss: 0.6154 - val_coeff_determination: -5794.0592
# Epoch 8/50
# 669/669 [==============================] - 0s 210us/step - loss: 0.6314 - coeff_determination: 0.0610 - val_loss: 0.6118 - val_coeff_determination: -5150.0799
# Epoch 9/50
# 669/669 [==============================] - 0s 214us/step - loss: 0.6299 - coeff_determination: 0.1838 - val_loss: 0.6160 - val_coeff_determination: -5513.7633
# Epoch 10/50
# 669/669 [==============================] - 0s 214us/step - loss: 0.6310 - coeff_determination: 0.1465 - val_loss: 0.6137 - val_coeff_determination: -5111.5960
# Epoch 11/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6309 - coeff_determination: 0.1162 - val_loss: 0.6115 - val_coeff_determination: -5062.1839
# Epoch 12/50
# 669/669 [==============================] - 0s 210us/step - loss: 0.6301 - coeff_determination: 0.1564 - val_loss: 0.6147 - val_coeff_determination: -4722.4583
# Epoch 13/50
# 669/669 [==============================] - 0s 210us/step - loss: 0.6310 - coeff_determination: 0.1300 - val_loss: 0.6155 - val_coeff_determination: -4652.5267
# Epoch 14/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6330 - coeff_determination: 0.1207 - val_loss: 0.6143 - val_coeff_determination: -4617.8114
# Epoch 15/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6316 - coeff_determination: 0.0500 - val_loss: 0.6170 - val_coeff_determination: -5395.4911
# Epoch 16/50
# 669/669 [==============================] - 0s 216us/step - loss: 0.6293 - coeff_determination: 0.1612 - val_loss: 0.6162 - val_coeff_determination: -4088.5058
# Epoch 17/50
# 669/669 [==============================] - 0s 212us/step - loss: 0.6304 - coeff_determination: 0.0353 - val_loss: 0.6156 - val_coeff_determination: -5947.5683
# Epoch 18/50
# 669/669 [==============================] - 0s 213us/step - loss: 0.6305 - coeff_determination: 0.0882 - val_loss: 0.6174 - val_coeff_determination: -4505.3649
# Epoch 19/50
# 669/669 [==============================] - 0s 212us/step - loss: 0.6322 - coeff_determination: 0.1249 - val_loss: 0.6136 - val_coeff_determination: -7275.9745
# Epoch 20/50
# 669/669 [==============================] - 0s 214us/step - loss: 0.6308 - coeff_determination: 0.1354 - val_loss: 0.6121 - val_coeff_determination: -5692.4880
# Epoch 21/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6290 - coeff_determination: 0.1743 - val_loss: 0.6134 - val_coeff_determination: -5084.2412
# Epoch 22/50
# 669/669 [==============================] - 0s 213us/step - loss: 0.6313 - coeff_determination: 0.1140 - val_loss: 0.6123 - val_coeff_determination: -5200.0123
# Epoch 23/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6298 - coeff_determination: 0.0859 - val_loss: 0.6163 - val_coeff_determination: -4783.9249
# Epoch 24/50
# 669/669 [==============================] - 0s 213us/step - loss: 0.6322 - coeff_determination: 0.0204 - val_loss: 0.6170 - val_coeff_determination: -4228.9741
# Epoch 25/50
# 669/669 [==============================] - 0s 210us/step - loss: 0.6322 - coeff_determination: 0.0986 - val_loss: 0.6128 - val_coeff_determination: -4436.9762
# Epoch 26/50
# 669/669 [==============================] - 0s 210us/step - loss: 0.6285 - coeff_determination: 0.1556 - val_loss: 0.6177 - val_coeff_determination: -5366.2838
# Epoch 27/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6299 - coeff_determination: 0.1121 - val_loss: 0.6123 - val_coeff_determination: -6050.5339
# Epoch 28/50
# 669/669 [==============================] - 0s 218us/step - loss: 0.6323 - coeff_determination: 0.1232 - val_loss: 0.6121 - val_coeff_determination: -4018.4745
# Epoch 29/50
# 669/669 [==============================] - 0s 215us/step - loss: 0.6306 - coeff_determination: 0.0767 - val_loss: 0.6145 - val_coeff_determination: -5073.0195
# Epoch 30/50
# 669/669 [==============================] - 0s 213us/step - loss: 0.6310 - coeff_determination: 0.1797 - val_loss: 0.6165 - val_coeff_determination: -4589.0590
# Epoch 31/50
# 669/669 [==============================] - 0s 215us/step - loss: 0.6315 - coeff_determination: 0.1428 - val_loss: 0.6138 - val_coeff_determination: -4568.4307
# Epoch 32/50
# 669/669 [==============================] - 0s 212us/step - loss: 0.6300 - coeff_determination: 0.0386 - val_loss: 0.6137 - val_coeff_determination: -3772.0377
# Epoch 33/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6331 - coeff_determination: 0.1203 - val_loss: 0.6131 - val_coeff_determination: -4560.2624
# Epoch 34/50
# 669/669 [==============================] - 0s 218us/step - loss: 0.6332 - coeff_determination: 0.1079 - val_loss: 0.6123 - val_coeff_determination: -4558.2865
# Epoch 35/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6317 - coeff_determination: 0.0870 - val_loss: 0.6148 - val_coeff_determination: -5354.2438
# Epoch 36/50
# 669/669 [==============================] - 0s 214us/step - loss: 0.6324 - coeff_determination: 0.1148 - val_loss: 0.6113 - val_coeff_determination: -6337.7357
# Epoch 37/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6318 - coeff_determination: 0.1236 - val_loss: 0.6167 - val_coeff_determination: -5664.7324
# Epoch 38/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6324 - coeff_determination: 0.0738 - val_loss: 0.6117 - val_coeff_determination: -4314.8644
# Epoch 39/50
# 669/669 [==============================] - 0s 214us/step - loss: 0.6336 - coeff_determination: 0.1261 - val_loss: 0.6154 - val_coeff_determination: -3893.7768
# Epoch 40/50
# 669/669 [==============================] - 0s 214us/step - loss: 0.6316 - coeff_determination: 0.0653 - val_loss: 0.6139 - val_coeff_determination: -4887.1715
# Epoch 41/50
# 669/669 [==============================] - 0s 210us/step - loss: 0.6313 - coeff_determination: 0.0517 - val_loss: 0.6207 - val_coeff_determination: -5309.2648
# Epoch 42/50
# 669/669 [==============================] - 0s 210us/step - loss: 0.6300 - coeff_determination: 0.1703 - val_loss: 0.6135 - val_coeff_determination: -5265.3945
# Epoch 43/50
# 669/669 [==============================] - 0s 212us/step - loss: 0.6331 - coeff_determination: 0.1425 - val_loss: 0.6123 - val_coeff_determination: -4495.7224
# Epoch 44/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6333 - coeff_determination: 0.0886 - val_loss: 0.6128 - val_coeff_determination: -5868.4179
# Epoch 45/50
# 669/669 [==============================] - 0s 211us/step - loss: 0.6344 - coeff_determination: 0.0246 - val_loss: 0.6138 - val_coeff_determination: -6930.5185
# Epoch 46/50
# 669/669 [==============================] - 0s 212us/step - loss: 0.6348 - coeff_determination: 0.0668 - val_loss: 0.6152 - val_coeff_determination: -5843.6363
# Epoch 47/50
# 669/669 [==============================] - 0s 212us/step - loss: 0.6302 - coeff_determination: 0.1495 - val_loss: 0.6138 - val_coeff_determination: -5793.8311
# Epoch 48/50
# 669/669 [==============================] - 0s 212us/step - loss: 0.6316 - coeff_determination: 0.0708 - val_loss: 0.6137 - val_coeff_determination: -5006.7795
# Epoch 49/50
# 669/669 [==============================] - 0s 214us/step - loss: 0.6289 - coeff_determination: 0.1108 - val_loss: 0.6127 - val_coeff_determination: -5052.8586
# Epoch 50/50
# 669/669 [==============================] - 0s 215us/step - loss: 0.6311 - coeff_determination: 0.1248 - val_loss: 0.6136 - val_coeff_determination: -4541.9463
# 1853/1853 [==============================] - 0s 31us/step
# 0.273023107183089
#
# ['linear', 'tanh', 'linear']
# 0.927182144624635

# %%
def model_hyperparam_search(layers, activation_functions=['tanh', 'softmax', 'relu']):
    iterations = len(activation_functions)**layers
    
    af_combs = make_pairwise_list(max_depth=layers, options=activation_functions)
    
    print(f'{layers}\t{activation_functions}\t{iterations} iterations required')
    for iteration in range(iterations):
        print(f"running interation {iteration}")
        print("create input layer")
        for layer in range(layers):
            print(f"create hidden layer {layer} of type {af_combs[iteration][layer]}")
        print("create output layer")
        print("")

def layer_search(hidden_layers=[1,3,5], 
                 activation_functions=None):
    for layer_count in hidden_layers:
        if not activation_functions:
            model_hyperparam_search(layer_count)
        else:
            model_hyperparam_search(layer_count, activation_functions)

# %%
def model__multi_search(X_train,Y_train,X_test,Y_test,input_dim,output_dim,layers,
                        activation_functions=['tanh', 'softmax', 'relu'],Dropout=[0.1,0.5,0.8]):
    iterations = (len(Dropout)*len(activation_functions))**(layers+2)
    inner_iterations = (len(Dropout)*len(activation_functions))**layers
    options= make_combo(option1=activation_functions,option2=Dropout)
    af_combs = make_pairwise_list(max_depth=layers, options=options)
    print(f'{layers}\t{activation_functions}\t{iterations} iterations required')
    best_R = 0.0
    best_param = []
    iteration_n = 1
    for n in range(layers):
        best_activation.append('none')
    best_activation = []
    for inner_iteration in range(inner_iterations):
        for option_in in options:
            for layer in range(layers):
                inner_list = []
                inner_list.append(af_combs[inner_iteration])
                for option_out in options:
                    print(f"running iteration {iteration_n}")
                    parameter_list1 = []
                    parameter_list.append(option_in)
                    parameter_list.extend(inner_list)
                    parameter_list.append(option_out)
                    print(f"create input layer with activation of {option_in[0]} and Dropout of {option_in[1]}")
                    
                    model = keras.Sequential()
                    model.add(keras.layers.Dense(10,input_dim = input_dim,activation=option_in[0],
                               Dropout = option_in[1]                 ))
                    for i in range(len(inner_list)):
                        print(f"create hidden layer {layer} of activation {inner_list[i][0]} and Dropout {inner_list[i][1]}")
                        model.add(keras.layers.Dense(20,activation = inner_list[i][0],Dropout = inner_list[i][1]))
                    print(f"create output layer with activation of {option_out[0]} and Dropout of {option_out[1]}")
                    model.add(keras.layers.Dense(output_dim,activation=option_out[0],Dropout=option_out[1]))
                    model.compile(loss='mean_squared_error', optimizer='adam', 
                                  metrics=[coeff_determination])
                    history = model.fit(X_train,Y_train,epochs=50, batch_size=10,validation_split=0.33)
                    scores = model.evaluate(X_test,Y_test)
                    
                    iteration_n += iteration_n 
                    if scores[1]>best_R:
                        best_param = parameter_list
                        best_score = scores[1]
                    else:
                        pass
        print("")
    print(best_param)
    print(best_R)
    return best_param

# %%
def make_pairwise_list(max_depth=2, options=['tanh', 'softmax', 'relu']):
    combinations = []
    for i in range(len(options)**max_depth):
        state = []
        for depth in range(max_depth):
            if depth == 0:
                #print(f"{i:4}:  {options[i // len(options)**(max_depth-1)]}", end='  ')
                state.append(options[i // len(options)**(max_depth-1)])
            elif depth == max_depth - 1:
                #print(f"{options[i % len(options)]}", end='  ')
                state.append(options[i % len(options)])
            else:
                #print(f"{options[i // len(options)**(depth) % len(options)]}", end='  ')
                state.append(options[i // len(options)**(depth) % len(options)])
        #print("")
        combinations.append(state)
    return combinations

# %%
# Not Run Yet
def Layer_Number_Decider(Number_Choice,input_dim,opt_activation,X,Y):
    Best_score = 0.0
    Best_L_Num = 1
    for choice_n in Number_Choice:
        i = 1
        model = Sequntial()
        while i <= choice n:
            model.add(keras.layers.Dense(5,input_dim=input_dim,activation=opt_activation))
        model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
        # Above step will be modified based on other functions to be completed
        model.fit(X,Y,epochs=150, batch_size=10,verbose=0)
        
        scores = model.evaluate(X,Y)
        if scores[1] > best_score:
            best_score = scores[1]
            best_L_Num = choice_n
                else:
                    pass
    
    print(best_score, L_num)

# %%
# The following function is Hand_written grid_Search Function
# Cross_validation is not included for runtime concerns
# This function has worked in other notebook.
def Grid_Search(param,X,Y):
    import keras
    best_score = 0.0
    best_activation = ['none','none','none']
    # This will be modified so that not only activation could be tuned
    # Also number of layers would be more flexible 
    for param1 in param:
        for param2 in param:
                model = keras.Sequential()
                model.add(keras.layers.Dense(20,input_dim=3,activation=param1))
                model.add(keras.layers.Dense(1,activation=param2))
                
                
                model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
                model.fit(X,Y,epochs=150, batch_size=10,verbose=0)
                
                scores = model.evaluate(X,Y)
                if scores[1] > best_score:
                    best_score = scores[1]
                    best_activation = [param1,param2]
                else:
                    pass
    
    print(best_score, best_activation)

# %%
# This script is copied and modified from web
# Take too long...
# Could be tried later with cluster or super computer
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor
from keras import Sequential
import keras
def create_model(activation='relu'):
	# create model
	model = Sequential()
	model.add(keras.layers.Dense(20, input_dim=3,activation=activation))
	model.add(keras.layers.Dense(1, activation='linear'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
	return model

# create model
model = KerasRegressor(build_fn=create_model, epochs=150, batch_size=10, verbose=0)
# define the grid search parameters
activation = ['tanh','linear','relu']
param_grid = dict(activation=activation)
# This param_grid could be a any other paramters:initializer, nodes_number,learning_rate
# learning momentum, drop_out rate,epoch, batch_size,weight_constraint,etc
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1)
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# %%
import xlrd
df2 = pd.read_excel('parameter_choice.xlsx')

# %%
df2.to_csv('parameter_choice.csv')

# %% [markdown]
# ##

# %%
df2
# Out:
#                      Parameters
# 0                  layer number
# 1                   layer type
# 2   different layer combination
# 3                  nodes number
# 4           activation function
# 5            kernel initializer
# 6              bias initializer
# 7            kernel regularizer
# 8              bias regularizer
# 9             kernel constraint
# 10             biase constraint
# 11                 Dropout rate
# 12                loss function
# 13                       metric
# 14  optimizer and learning rate
# 15                       epochs
# 16                   batch_size

# %% [markdown]
# ## This to do next:
# * Find a way to make every function work: shrinking pre_trained sample size, split parameter
#   and do them one by one, Forward_stepwise selection...?
# * Data preprossing and standardizing function
# * Model restoring function
# * Plot Draw~
# * .Py Script
# * Other kinds of neural network and layers
# * Probably some sel_designing parameter/functions such as weight initilizer
